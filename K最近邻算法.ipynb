# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
data = make_blobs(n_samples=200,centers=2,random_state=8)
X,y=data
y
count=0
for i in y:
    if i ==0:
        count+=1
        
count
# Out:
# 100

# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
data2 = make_blobs(n_samples=500,centers=5,random_state=8)
X2,y2=data2
#plt.scatter(X2[:,0],X2[:,1],c=y2,cmap=plt.cm.spring,edgecolor='k')
#plt.show()

import numpy as np
clf = KNeighborsClassifier()
clf.fit(X2,y2)

x_min,x_max = X2[:,0].min()-1,X2[:,0].max()+1
y_min,y_max = X2[:,1].min()-1,X2[:,1].max()+1
t1 = np.linspace(x_min,x_max,200)
t2 = np.linspace(y_min,y_max,200)
x1,x2 = np.meshgrid(t1,t2)
x_show = np.stack((x1.flat,x2.flat),axis = 1)
y_show = clf.predict(x_show).reshape(x1.shape)
#xx,yy = numpy.meshgrid(numpy.arange(x_min,x_max,.02),numpy.arange(y_min,y_max,.02))
#Z = clf.predict(numpy.c_[xx.ravel(),yy.ravel()])
#Z = Z.reshape(xx.shape)
plt.pcolormesh(x1,x2,y_show,cmap=plt.cm.Pastel1)
plt.scatter(X2[:,0],X2[:,1],c=y2,cmap=plt.cm.spring,edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title("Classifier:KNN")

plt.show()
print('模型正确率：',clf.score(X2,y2))
# Out:
# 模型正确率： 0.956

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor

X,y = make_regression(n_features=1,n_informative=1,noise=50,random_state=8)

reg = KNeighborsRegressor(n_neighbors=2)
reg.fit(X,y)
z = np.linspace(-3,3,200).reshape(-1,1)
plt.plot(X,y,'g*')
plt.plot(z,reg.predict(z),c='red',linewidth=2)
plt.title('KNN Regressor')
plt.show()

# %%
from sklearn.datasets import load_wine
wine_dataset = load_wine()
X_train,X_test,y_train,y_test = train_test_split(wine_dataset['data'],wine_dataset['target'],random_state=0)

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
print('测试数据集的得分：{:.2f}'.format(knn.score(X_test,y_test)))
X_new = numpy.array([[13.2,2.77,2.51,18.5,96.6,1.04,2.55,0.57,1.47,6.2,1.05,3.33,820]])
prediction = knn.predict(X_new)
print('代码运行结果：')
print('=======================')
print('预测新酒的分类为：',wine_dataset['target_names'][prediction])
# Out:
# 测试数据集的得分：0.76
# 代码运行结果：
# ...
# 预测新酒的分类为： ['class_2']
